# %%
from kaggle_environments import make
import json
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2}, debug=True)
steps = env.run(["./agent.py", "./agent.py"])
# Out:
# [WARN] (match_WwnUHyShQxWh) - turn 12; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 12; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 23; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 23; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 30; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 30; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - turn 30; Unit u_1 collided when trying to move e to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 3; turn 31; cmd: m u_2 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 3; turn 32; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 2; turn 32; cmd: m u_2 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 2; turn 33; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 1; turn 33; cmd: m u_2 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 34; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - turn 41; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 41; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 52; Unit u_7 collided when trying to move s to (0, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 52; Unit u_8 collided when trying to move s to (31, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 69; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 69; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 1; turn 70; cmd: m u_9 n
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 1; turn 70; cmd: m u_10 n
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 3; turn 72; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 3; turn 72; cmd: m u_10 e
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 2; turn 73; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 2; turn 73; cmd: m u_10 e
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 1; turn 74; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 1; turn 74; cmd: m u_10 e
# [WARN] (match_WwnUHyShQxWh) - turn 81; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 81; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 84; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 84; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 88; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 88; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 90; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 90; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 93; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 93; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 97; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 97; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 99; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 99; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 102; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 102; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 106; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 106; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 108; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 108; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 110; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 1; turn 110; cmd: m u_2 n
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 110; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 3; turn 111; cmd: m u_1 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 2; turn 112; cmd: m u_1 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 3; turn 112; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 3; turn 112; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 113; cmd: m u_1 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 2; turn 113; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 2; turn 113; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 114; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 114; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - turn 121; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 121; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 124; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 124; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 128; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 128; Unit u_9 collided when trying to move n to (4, 27)
# [WARN] (match_WwnUHyShQxWh) - turn 128; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 128; Unit u_10 collided when trying to move n to (27, 27)
# [WARN] (match_WwnUHyShQxWh) - turn 130; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 130; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 133; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 133; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 137; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 137; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 139; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 139; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 142; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 142; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 146; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 146; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 148; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 148; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 150; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 150; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 1; turn 150; cmd: m u_10 e
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 3; turn 151; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 3; turn 152; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 2; turn 152; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 3; turn 152; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 2; turn 153; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 1; turn 153; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 2; turn 153; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 154; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 154; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - turn 161; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 161; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 164; Unit u_5 collided when trying to move s to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 164; Unit u_6 collided when trying to move s to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 168; Unit u_9 collided when trying to move n to (4, 27)
# [WARN] (match_WwnUHyShQxWh) - turn 170; Unit u_5 collided when trying to move n to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 170; Unit u_6 collided when trying to move n to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 171; Unit u_2 collided when trying to move e to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 171; Unit u_10 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 172; Unit u_2 collided when trying to move e to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 172; Unit u_10 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 173; Unit u_2 collided when trying to move e to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 173; Unit u_10 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 175; Unit u_10 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 177; Unit u_2 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 178; Unit u_2 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 179; Unit u_2 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 180; Unit u_2 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 181; Unit u_1 collided when trying to move w to (3, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 182; Unit u_1 collided when trying to move w to (3, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 182; Unit u_5 collided when trying to move n to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 182; Unit u_6 collided when trying to move n to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 182; Unit u_10 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 188; Unit u_8 collided when trying to move n to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 190; cmd: m u_1 n
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 1; turn 190; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 190; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 1; turn 190; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 1; turn 190; cmd: m u_2 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 190; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_8 with cooldown: 1; turn 190; cmd: m u_8 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 1; turn 190; cmd: m u_10 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 3; turn 192; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_8 with cooldown: 3; turn 192; cmd: m u_8 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 3; turn 192; cmd: m u_10 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 2; turn 193; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_8 with cooldown: 2; turn 193; cmd: m u_8 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 2; turn 193; cmd: m u_10 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 1; turn 194; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_8 with cooldown: 1; turn 194; cmd: m u_8 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_10 with cooldown: 1; turn 194; cmd: m u_10 s
# [WARN] (match_WwnUHyShQxWh) - turn 201; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 201; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 201; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 203; Unit u_9 collided when trying to move s to (4, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 204; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 205; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 206; Unit u_5 collided when trying to move s to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 206; Unit u_6 collided when trying to move s to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 207; Unit u_5 collided when trying to move s to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 209; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 211; Unit u_1 collided when trying to move w to (3, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 211; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 212; Unit u_6 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 213; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 214; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 214; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 215; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 215; Unit u_2 collided when trying to move e to (29, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 216; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 217; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 218; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 218; Unit u_11 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 219; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 220; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 221; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 221; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 221; Unit u_6 collided when trying to move s to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 222; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 222; Unit u_6 collided when trying to move s to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 223; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 223; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 223; Unit u_6 collided when trying to move s to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 224; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 224; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 224; Unit u_6 collided when trying to move s to (30, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 225; Unit u_3 collided when trying to move n to (2, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 225; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 225; Unit u_10 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 226; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 227; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 227; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 228; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 228; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 228; Unit u_8 collided when trying to move n to (30, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 229; Unit u_5 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 229; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 1; turn 230; cmd: m u_9 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_8 with cooldown: 1; turn 230; cmd: m u_8 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 3; turn 231; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 3; turn 231; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 2; turn 232; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 2; turn 232; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 3; turn 232; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 233; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 1; turn 233; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 2; turn 233; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_9 with cooldown: 1; turn 234; cmd: m u_9 w
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to build unit on tile (29, 27) but unit cap reached. Build more CityTiles!; turn 240; cmd: bw 29 27
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to build unit on tile (30, 27) but unit cap reached. Build more CityTiles!; turn 240; cmd: bw 30 27
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to build unit on tile (31, 27) but unit cap reached. Build more CityTiles!; turn 240; cmd: bw 31 27
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to build unit on tile (31, 28) but unit cap reached. Build more CityTiles!; turn 240; cmd: bw 31 28
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to build unit on tile (28, 26) but unit cap reached. Build more CityTiles!; turn 240; cmd: bw 28 26
# [WARN] (match_WwnUHyShQxWh) - turn 241; Unit u_7 collided when trying to move n to (1, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 241; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 246; Unit u_5 collided when trying to move s to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 246; Unit u_7 collided when trying to move n to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 246; Unit u_2 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 246; Unit u_11 collided when trying to move s to (28, 28)
# [WARN] (match_WwnUHyShQxWh) - turn 247; Unit u_5 collided when trying to move s to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 247; Unit u_7 collided when trying to move n to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 249; Unit u_7 collided when trying to move n to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 252; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 254; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 256; Unit u_7 collided when trying to move s to (1, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 258; Unit u_3 collided when trying to move s to (2, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 259; Unit u_3 collided when trying to move s to (2, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 259; Unit u_2 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 261; Unit u_10 collided when trying to move e to (29, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 262; Unit u_9 collided when trying to move w to (3, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 265; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 265; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 266; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 267; Unit u_1 collided when trying to move s to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 267; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 267; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 267; Unit u_10 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 268; Unit u_1 collided when trying to move s to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 268; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 269; Unit u_1 collided when trying to move s to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 269; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 269; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 3; turn 271; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 3; turn 271; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 3; turn 271; cmd: m u_2 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 3; turn 271; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 2; turn 272; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 2; turn 272; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 2; turn 272; cmd: m u_2 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 2; turn 272; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 273; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 1; turn 273; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_2 with cooldown: 1; turn 273; cmd: m u_2 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 273; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 3; turn 275; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 2; turn 276; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 1; turn 277; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to build unit on tile (2, 27) but unit cap reached. Build more CityTiles!; turn 280; cmd: bw 2 27
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to build unit on tile (1, 27) but unit cap reached. Build more CityTiles!; turn 280; cmd: bw 1 27
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to build unit on tile (0, 27) but unit cap reached. Build more CityTiles!; turn 280; cmd: bw 0 27
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to build unit on tile (0, 28) but unit cap reached. Build more CityTiles!; turn 280; cmd: bw 0 28
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to build unit on tile (3, 26) but unit cap reached. Build more CityTiles!; turn 280; cmd: bw 3 26
# [WARN] (match_WwnUHyShQxWh) - turn 281; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 281; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 286; Unit u_1 collided when trying to move s to (2, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 286; Unit u_2 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 289; Unit u_2 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 289; Unit u_4 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 289; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 290; Unit u_2 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 290; Unit u_4 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 290; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 292; Unit u_1 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 292; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 293; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 293; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 294; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 294; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 294; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 295; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 295; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 296; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 296; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 296; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 297; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 297; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 298; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 298; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 299; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 299; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 300; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 300; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 301; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 301; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 302; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 302; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 303; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 303; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 304; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 304; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 305; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 305; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 306; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 306; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 307; Unit u_3 collided when trying to move s to (2, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 307; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 307; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 308; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 308; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 309; Unit u_5 collided when trying to move w to (2, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 309; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 309; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 3; turn 311; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 3; turn 311; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 3; turn 311; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 3; turn 311; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_4 with cooldown: 3; turn 311; cmd: m u_4 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 3; turn 311; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 2; turn 312; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 2; turn 312; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 2; turn 312; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 2; turn 312; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_4 with cooldown: 2; turn 312; cmd: m u_4 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 2; turn 312; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 313; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 1; turn 313; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 313; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_7 with cooldown: 1; turn 313; cmd: m u_7 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_4 with cooldown: 1; turn 313; cmd: m u_4 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 313; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 3; turn 315; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 2; turn 316; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_1 with cooldown: 1; turn 317; cmd: m u_1 s
# [WARN] (match_WwnUHyShQxWh) - turn 321; Unit u_3 collided when trying to move n to (2, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 321; Unit u_4 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 326; Unit u_1 collided when trying to move s to (2, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 326; Unit u_2 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 329; Unit u_2 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 329; Unit u_4 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 329; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 330; Unit u_2 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 330; Unit u_4 collided when trying to move s to (29, 25)
# [WARN] (match_WwnUHyShQxWh) - turn 330; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 332; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 333; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 333; Unit u_10 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 334; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 334; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 335; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 335; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 336; Unit u_1 collided when trying to move n to (2, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 336; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 336; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 337; Unit u_1 collided when trying to move n to (2, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 337; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 337; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 338; Unit u_1 collided when trying to move n to (2, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 338; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 338; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 339; Unit u_1 collided when trying to move n to (2, 24)
# [WARN] (match_WwnUHyShQxWh) - turn 339; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 339; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 340; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 340; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 341; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 341; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 342; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 342; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 343; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 343; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 344; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 344; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 345; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 345; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 346; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 346; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 347; Unit u_5 collided when trying to move e to (4, 27)
# [WARN] (match_WwnUHyShQxWh) - turn 347; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 347; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 348; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 348; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 349; Unit u_2 collided when trying to move n to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - turn 349; Unit u_4 collided when trying to move s to (29, 26)
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 1; turn 350; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 350; cmd: m u_5 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 3; turn 351; cmd: m u_13 n
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_4 with cooldown: 3; turn 351; cmd: m u_4 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 3; turn 351; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 3; turn 352; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 2; turn 352; cmd: m u_13 n
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_4 with cooldown: 2; turn 352; cmd: m u_4 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 2; turn 352; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 2; turn 353; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 1; turn 353; cmd: m u_13 n
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_4 with cooldown: 1; turn 353; cmd: m u_4 s
# [WARN] (match_WwnUHyShQxWh) - Agent 1 tried to move unit u_6 with cooldown: 1; turn 353; cmd: m u_6 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_3 with cooldown: 1; turn 354; cmd: m u_3 s
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 3; turn 355; cmd: m u_13 n
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 2; turn 356; cmd: m u_13 n
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 1; turn 357; cmd: m u_13 n
# [WARN] (match_WwnUHyShQxWh) - Agent 0 tried to move unit u_13 with cooldown: 3; turn 359; cmd: m u_13 w

# %%
env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;8e335687-210a-11ec-bb70-c8b29bdfa6b4&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 562124210,
#       &quot;loglevel&quot;: 2,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;annotations&quot;: false,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 32,
#             &quot;height&quot;: 32,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;32 32&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 29 316&quot;,
#               &quot;r wood 1 24 342&quot;,
#               &quot;r wood 1 25 323&quot;,
#               &quot;r uranium 1 31 332&quot;,
#               &quot;r wood 2 24 329&quot;,
#               &quot;r wood 2 25 397&quot;,
#               &quot;r wood 2 26 364&quot;,
#               &quot;r uranium 2 31 346&quot;,
#               &quot;r wood 3 28 800&quot;,
#               &quot;r wood 4 10 318&quot;,
#               &quot;r wood 4 11 398&quot;,
#               &quot;r uranium 4 17 336&quot;,
#               &quot;r wood 4 27 800&quot;,
#               &quot;r wood 4 28 800&quot;,
#               &quot;r wood 5 10 308&quot;,
#               &quot;r wood 5 11 326&quot;,
#               &quot;r uranium 5 17 335&quot;,
#               &quot;r coal 7 31 355&quot;,
#               &quot;r coal 8 0 369&quot;,
#               &quot;r coal 8 30 404&quot;,
#               &quot;r coal 8 31 422&quot;,
#               &quot;r wood 11 23 317&quot;,
#               &quot;r wood 11 24 330&quot;,
#               &quot;r wood 11 25 314&quot;,
#               &quot;r wood 12 23 349&quot;,
#               &quot;r wood 12 24 390&quot;,
#               &quot;r wood 13 6 337&quot;,
#               &quot;r wood 13 7 325&quot;,
#               &quot;r wood 13 24 374

# %%
# %%writefile agent.py

from io import TextIOBase
import math, sys
from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES, GameMap
from lux.constants import Constants
from lux.game_constants import GAME_CONSTANTS
from lux import annotate
import logging 
import numpy

with open('basicLog.log', 'w'):
    pass

logging.basicConfig(filename="basicLog.log", level = logging.INFO)

DIRECTIONS = Constants.DIRECTIONS
game_state = None
build_location = None
night_flag = False
logging_str = []

def log_function(log_entry):
    global logging_str
    logging_str.append(log_entry)
    logging.info(log_entry)
    logging.info(f"{logging_str=}")
    

def get_resource_tiles(game_state, width, height):
    resource_tiles: list[Cell] = []
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            if cell.has_resource():
                resource_tiles.append(cell)
    return resource_tiles

def get_closest_resource(unit, resource_tiles, player):
    closest_dist = math.inf
    closest_resource_tile = None

    unit_pos_list = []
    for u in player.units:
        unit_pos_list.append(u.pos)

    if unit.get_cargo_space_left() > 0:
        # if the unit is a worker and we have space in cargo, lets find the nearest resource tile and try to mine it
        for resource_tile in resource_tiles:
            if resource_tile.resource.type == Constants.RESOURCE_TYPES.COAL and not player.researched_coal(): continue
            if resource_tile.resource.type == Constants.RESOURCE_TYPES.URANIUM and not player.researched_uranium(): continue
            dist = resource_tile.pos.distance_to(unit.pos)
            if dist < closest_dist and resource_tile.pos not in unit_pos_list:
                closest_dist = dist
                closest_resource_tile = resource_tile
                
    return closest_resource_tile

def get_closest_city_tile(player,unit):
    closest_dist = math.inf
    closest_city_tile = None
    for k, city in player.cities.items():
        for city_tile in city.citytiles:
            dist = city_tile.pos.distance_to(unit.pos)
            if dist < closest_dist:
                closest_dist = dist
                closest_city_tile = city_tile
    return closest_city_tile

def get_closest_empty_city_tile(player,unit):
    closest_dist = math.inf
    closest_city_tile = None

    unit_pos_list = []
    for u in player.units:
        unit_pos_list.append(u.pos)
    log_function(f"Unit pos list {unit_pos_list}")
    for k, city in player.cities.items():
        for city_tile in city.citytiles:
            dist = city_tile.pos.distance_to(unit.pos)
            if (dist < closest_dist) and (city_tile.pos not in unit_pos_list):
                closest_dist = dist
                closest_city_tile = city_tile
    return closest_city_tile


def get_burn_rate(player):
    burn_rate = 0
    for key,city in player.cities:
        burn_rate = burn_rate + city.get_light_upkeep()
    return burn_rate

def get_simple_path(unit, dest):
    global game_state
    (dx, dy) = (dest.pos.x-unit.pos.x, dest.pos.y-unit.pos.y)
    sign = lambda a: (a>0) - (a<0)
    log_function(f"unit pos = {unit.pos.x, unit.pos.y}, dx = {dx}, dy = {dy}")
    cell_x_dir = game_state.map.get_cell(unit.pos.x+sign(dx), unit.pos.y)
    cell_y_dir = game_state.map.get_cell(unit.pos.x, unit.pos.y+sign(dy))
    if (not dx) or cell_x_dir.citytile:
        log_function(f"moving to {[cell_y_dir.pos.x,cell_y_dir.pos.y]}")
        return cell_y_dir
    elif dx:
        log_function(f"moving to {[cell_x_dir.pos.x,cell_x_dir.pos.y-sign(dy)]}")
        return cell_x_dir



def night_move(player,unit):
    global game_state
    close_home = get_closest_city_tile(player,unit)
    
    if not close_home:
        log_function(f"No Home available for {unit}")
        return unit.move("C")
    else:
        log_function(f"Closest home for unit {unit} is {close_home.pos}")
        return unit.move(unit.pos.direction_to(close_home.pos))
    

def build_city_action(game_state, player, unit):
    global build_location
    empty_near = get_closest_city_tile(player,unit)
    while build_location==None:
        log_function(f"Nearest City is {[empty_near.pos.x, empty_near.pos.y]}")
        dirs = [(1,0),(-1,0),(0,1),(0,-1)]
        for d in dirs:
            try:
                check_tile = game_state.map.get_cell(empty_near.pos.x+d[0],empty_near.pos.y+d[1])
                log_function(f": Checking {[check_tile.pos.x,check_tile.pos.y]}")

                if check_tile.resource == None and check_tile.road == 0 and check_tile.citytile == None:
                    build_location = check_tile
                    log_function(f"{game_state.turn} Found {[check_tile.pos.x,check_tile.pos.y]}")
                    get_cell_build_value(game_state, build_location)
                    break
            except Exception as e:
                logging.warning(f"{game_state.turn, str(e)} broke")
        if not build_location:
            empty_near = game_state.map.get_cell(empty_near.pos.x+d[0]*2,empty_near.pos.y+d[1]*2)

    if (build_location) and unit.pos == build_location.pos:
        log_function(f"{game_state.turn} build: At Location Building City")
        build_location=None
        return unit.build_city()
    elif (build_location):
        log_function(f"{game_state.turn} Moving to  Build location = {build_location}")
        move_cell = get_simple_path(unit, build_location)
        move_dir = unit.pos.direction_to(move_cell.pos)


        log_function(f"build: Moving in Dir {[move_dir]}")
        return unit.move(move_dir)

def resource_sum(unit):
    return unit.cargo.wood+unit.cargo.coal+unit.cargo.uranium

def get_cell_build_value(game_state, centre_cell):
    close_c_list = []
    cell_build_val = 0
    for r in game_state.map.map:
        #log_function(f"{r=}")
        for c in r:
            if centre_cell.pos.distance_to(c.pos)==1:
                close_c_list.append(c)
                if c.has_resource():
                    cell_build_val += 1
    log_function(f"Checked Cell {centre_cell.pos}, {cell_build_val=}")
    return cell_build_val





def agent(observation, configuration):
    global game_state
    global build_location
    global night_flag
    global logging_str
    ### Do not edit ###
    if observation["step"] == 0:
        game_state = Game()
        game_state._initialize(observation["updates"])
        game_state._update(observation["updates"][2:])
        game_state.id = observation.player
    else:
        game_state._update(observation["updates"])
    
    actions = []
    step = observation["step"]
    log_function(f"----- turn = {observation['step']} ----- ")

    ### AI Code goes down here! ### 
    player = game_state.players[observation.player]
    opponent = game_state.players[(observation.player + 1) % 2]
    width, height = game_state.map.width, game_state.map.height
    cities = player.cities.values()
    city_tiles = []

    if observation["step"]%40>29:
        night_flag = True
    else:
        night_flag = False

    for city in cities:
        for c_tile in city.citytiles:
            city_tiles.append(c_tile.pos)

    workers = []
    for worker in player.units:
        if worker.is_worker:
            workers.append(worker)

    resource_tiles = get_resource_tiles(game_state,width,height)
    
    #log_function(f"{cities}")
    #log_function(f"{city_tiles}")

    build_city_flag = False
    if len(city_tiles) <= len(workers):
        build_city_flag = True
        builder_unit = player.units[0]

    build_worker_flag = False
    if len(city_tiles)>len(workers):
        build_worker_flag = True

    move_pos_list = []

    # we iterate over all our units and do something with them
    for unit in player.units:
        if night_flag:
            log_function("Its night")
            if unit.pos in city_tiles:
                continue
            else:
                actions.append(night_move(player,unit))
        elif unit.is_worker() and unit.can_act():
            closest_resource_tile = get_closest_resource(unit, resource_tiles, player) 
            closest_city_tile = get_closest_city_tile(player,unit)

            if build_city_flag and (resource_sum(unit) == 100) and unit.id == builder_unit.id:
                log_function(f"Attempt City Build")
                actions.append(build_city_action(game_state,player,unit))
            elif closest_resource_tile is not None:
                if closest_resource_tile not in move_pos_list:
                    move_pos_list.append(closest_resource_tile)
                    actions.append(unit.move(unit.pos.direction_to(closest_resource_tile.pos)))
                else:
                    continue

            else:
            # if unit is a worker and there is no cargo space left, and we have cities, lets return to them
                if len(player.cities) > 0:
                    
                    if closest_city_tile is not None:
                        move_dir = unit.pos.direction_to(closest_city_tile.pos)
                        actions.append(unit.move(move_dir))

    for k,c in player.cities.items():
        for ct in c.citytiles:
            if ct.can_act() and not night_flag:
                if build_worker_flag:
                    log_function("Building Worker")
                    actions.append(ct.build_worker())
                else:
                    actions.append(ct.research())
    # you can add debug annotations using the functions in the annotate object
    for s in logging_str:
        actions.append(annotate.sidetext(f"{s}"))
    logging_str = []
    actions.append(annotate.sidetext(f"{s}"))
    return actions
# Out:
# Overwriting agent.py

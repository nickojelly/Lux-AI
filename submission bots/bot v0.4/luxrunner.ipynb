# %%
from kaggle_environments import make
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
from agent import *

# %%
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)

# %%
import sys
import os
print(f"{os.getcwd()=}")
sys.path.append('/attempt 2')
sys.path.append('/attempt 3')  
steps = env.run(['./attempt 2/agent.py','./attempt 2/agent.py'])
# Out:
# os.getcwd()='c:\\Users\\Nick\\Documents\\GitHub\\Lux-AI\\bot v0.4'
# Traceback (most recent call last):
#   File "C:\Users\Nick\.conda\envs\pytorch\lib\site-packages\kaggle_environments\agent.py", line 43, in get_last_callable
#     code_object = compile(raw, path, "exec")
#   File "./attempt 2/agent.py", line 1
#     ./attempt 2/agent.py
#     ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Nick\.conda\envs\pytorch\lib\site-packages\kaggle_environments\agent.py", line 157, in act
#     action = self.agent(*args)
#   File "C:\Users\Nick\.conda\envs\pytorch\lib\site-packages\kaggle_environments\agent.py", line 123, in callable_agent
#     agent = get_last_callable(raw_agent, path=raw) or raw_agent
#   File "C:\Users\Nick\.conda\envs\pytorch\lib\site-packages\kaggle_environments\agent.py", line 64, in get_last_callable
# ...

# %%
env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: false,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: false,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;38eb97a4-27f5-11ec-b299-c8b29bdfa6b4&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 562124210,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
# ...

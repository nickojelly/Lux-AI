# %%
from kaggle_environments import make
#env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)
#env = make("lux_ai_2021", configuration={"seed": 872178612, "loglevel": 2, "annotations": True}, debug=True)418374047
#255052476
#env = make("lux_ai_2021", configuration={"seed":255052476, "loglevel": 2, "annotations": True}, debug=True)
env = make("lux_ai_2021", configuration={ "loglevel": 2, "annotations": True}, debug=True)
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
import sys
import os
print(f"{os.getcwd()=}")
sys.path.append(r"C:\Users\Nick\Documents\GitHub\Lux-AI\attempt 2")
sys.path.append(r"C:\Users\Nick\Documents\GitHub\Lux-AI\attempt 3")  
steps = env.run(['./bot v0.7/agent.py','./simple.tar/agent.py'])
# Out:
# os.getcwd()='c:\\Users\\Nick\\Documents\\GitHub\\Lux-AI\\RuleBots'
# [WARN] (match_LKo4O5dUcK8o) - turn 16; Unit u_4 collided when trying to move n to (9, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (10, 12) but unit cap reached. Build more CityTiles!; turn 25; cmd: bw 10 12
# [WARN] (match_LKo4O5dUcK8o) - turn 82; Unit u_6 collided when trying to move s to (8, 14)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 sent an extra command. Unit can perform only one action at a time; turn 88; cmd: m u_3 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (10, 13) but unit cap reached. Build more CityTiles!; turn 107; cmd: bw 10 13
# [WARN] (match_LKo4O5dUcK8o) - turn 128; Unit u_8 collided when trying to move s to (9, 15)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (1, 2) but unit cap reached. Build more CityTiles!; turn 129; cmd: bw 1 2
# [WARN] (match_LKo4O5dUcK8o) - turn 136; Unit u_8 collided when trying to move s to (9, 15)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 sent an extra command. Unit can perform only one action at a time; turn 142; cmd: m u_3 e
# [WARN] (match_LKo4O5dUcK8o) - turn 177; Unit u_6 collided when trying to move n to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 180; Unit u_8 collided when trying to move s to (11, 12)
# [WARN] (match_LKo4O5dUcK8o) - turn 180; Unit u_9 collided when trying to move e to (11, 12)
# [WARN] (match_LKo4O5dUcK8o) - turn 201; Unit u_11 collided when trying to move e to (23, 2)
# [WARN] (match_LKo4O5dUcK8o) - turn 202; Unit u_4 collided when trying to move s to (11, 12)
# [WARN] (match_LKo4O5dUcK8o) - turn 202; Unit u_11 collided when trying to move e to (23, 2)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_11 off map; turn 208; cmd: m u_11 e
# [WARN] (match_LKo4O5dUcK8o) - turn 208; Unit u_10 collided when trying to move e to (23, 2)
# [WARN] (match_LKo4O5dUcK8o) - turn 209; Unit u_9 collided when trying to move e to (11, 12)
# [WARN] (match_LKo4O5dUcK8o) - turn 210; Unit u_9 collided when trying to move e to (11, 12)
# [WARN] (match_LKo4O5dUcK8o) - turn 213; Unit u_8 collided when trying to move n to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 213; Unit u_9 collided when trying to move e to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 213; Unit u_6 collided when trying to move n to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 214; Unit u_4 collided when trying to move s to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 214; Unit u_9 collided when trying to move e to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 218; Unit u_8 collided when trying to move e to (11, 12)
# [WARN] (match_LKo4O5dUcK8o) - turn 225; Unit u_5 collided when trying to move w to (5, 14)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (11, 13) but unit cap reached. Build more CityTiles!; turn 244; cmd: bw 11 13
# [WARN] (match_LKo4O5dUcK8o) - turn 249; Unit u_14 collided when trying to move w to (5, 14)
# [WARN] (match_LKo4O5dUcK8o) - turn 251; Unit u_14 collided when trying to move w to (5, 14)
# [WARN] (match_LKo4O5dUcK8o) - turn 254; Unit u_11 collided when trying to move s to (23, 2)
# [WARN] (match_LKo4O5dUcK8o) - turn 256; Unit u_9 collided when trying to move w to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 257; Unit u_14 collided when trying to move w to (5, 14)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 259; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 260; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 260; Unit u_6 collided when trying to move n to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 261; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_11 off map; turn 261; cmd: m u_11 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 262; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 262; Unit u_6 collided when trying to move n to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 263; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 264; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 265; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 266; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 267; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 280; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 281; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 282; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 282; Unit u_11 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 283; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 284; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 285; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 286; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 287; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 288; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 289; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 289; Unit u_12 collided when trying to move e to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 290; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 290; Unit u_12 collided when trying to move e to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 291; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 291; Unit u_10 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 292; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 293; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 294; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 294; Unit u_13 collided when trying to move e to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 295; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 296; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 297; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 298; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 299; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 300; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 301; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 302; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 302; Unit u_9 collided when trying to move w to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 303; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 304; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 305; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 306; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 306; Unit u_8 collided when trying to move n to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 306; Unit u_17 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 307; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 307; Unit u_8 collided when trying to move n to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 320; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 321; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 322; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 322; Unit u_17 collided when trying to move e to (23, 2)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 323; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 324; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 324; Unit u_9 collided when trying to move e to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 325; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 325; Unit u_9 collided when trying to move w to (9, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 325; Unit u_17 collided when trying to move s to (23, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 326; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 327; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 327; Unit u_8 collided when trying to move s to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 328; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 328; Unit u_8 collided when trying to move s to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 328; Unit u_11 collided when trying to move w to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 329; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 329; Unit u_8 collided when trying to move s to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 330; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 331; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 332; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 333; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 333; Unit u_9 collided when trying to move n to (11, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 334; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 335; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 336; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 336; Unit u_11 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 337; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 338; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 339; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 339; Unit u_10 collided when trying to move e to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 340; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 340; Unit u_10 collided when trying to move n to (21, 2)
# [WARN] (match_LKo4O5dUcK8o) - turn 340; Unit u_17 collided when trying to move w to (21, 2)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 341; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 341; Unit u_9 collided when trying to move n to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - turn 341; Unit u_10 collided when trying to move n to (21, 2)
# [WARN] (match_LKo4O5dUcK8o) - turn 341; Unit u_17 collided when trying to move w to (21, 2)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 342; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 342; Unit u_17 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 343; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 344; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 344; Unit u_11 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 345; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 345; Unit u_8 collided when trying to move e to (10, 11)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 346; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - turn 346; Unit u_10 collided when trying to move s to (22, 3)
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to move unit u_4 onto opponent CityTile; turn 347; cmd: m u_4 e
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (9, 13) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 9 13
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (9, 12) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 9 12
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (10, 12) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 10 12
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (10, 13) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 10 13
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (10, 14) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 10 14
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (8, 14) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 8 14
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (11, 12) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 11 12
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (11, 13) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 11 13
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (1, 2) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 1 2
# [WARN] (match_LKo4O5dUcK8o) - Agent 0 tried to build unit on tile (22, 2) but unit cap reached. Build more CityTiles!; turn 351; cmd: bw 22 2

# %%
env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;d0d1db8e-4101-11ec-88a1-c8b29bdfa6b4&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;seed&quot;: 307844644,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 24,
#             &quot;height&quot;: 24,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;24 24&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 2 357&quot;,
#               &quot;r wood 0 3 325&quot;,
#               &quot;r wood 0 4 352&quot;,
#               &quot;r uranium 0 8 315&quot;,
#               &quot;r coal 0 12 411&quot;,
#               &quot;r coal 0 13 359&quot;,
#               &quot;r uranium 0 18 305&quot;,
#               &quot;r wood 1 1 304&quot;,
#               &quot;r wood 1 4 356&quot;,
#               &quot;r uranium 1 8 343&quot;,
#               &quot;r coal 1 12 380&quot;,
#               &quot;r coal 1 13 392&quot;,
#               &quot;r uranium 1 18 348&quot;,
#               &quot;r uranium 1 19 323&quot;,
#               &quot;r coal 2 13 414&quot;,
#               &quot;r wood 3 23 382&quot;,
#               &quot;r coal 4 14 362&quot;,
#               &quot;r wood 4 23 398&quot;,
#               &quot;r wood 8 13 800&quot;,
#               &quot;r wood 8 14 800&quot;,
#               &quot;r wood 8 15 800&quot;,
#               &quot;r wood 9 0 305&quot;,
#               &quot;r wood 9 1 356&quot;,
#               &quot;r wood 9 2 315&quot;,
#               &quot;r wood 10 0 316&quot;,
#               &quot;r wood 10 1 377&quot;,
#               &quot;r wood 10 11 306&quot;,
#               &quot;r uranium 10 23 338&quot;,
#               &quot;r wood 11 11 373&quot;,

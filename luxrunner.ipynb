# %%
from kaggle_environments import make
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)
#env = make("lux_ai_2021", configuration={ "loglevel": 2, "annotations": True}, debug=True)
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
import sys
import os
print(f"{os.getcwd()=}")
sys.path.append(r"C:\Users\Nick\Documents\GitHub\Lux-AI\attempt 2")
sys.path.append(r"C:\Users\Nick\Documents\GitHub\Lux-AI\attempt 3")  
steps = env.run(['./bot v0.5/agent.py','./simple.tar/agent.py'])
# Out:
# os.getcwd()='c:\\Users\\Nick\\Documents\\GitHub\\Lux-AI'
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_3 with cooldown: 3; turn 35; cmd: m u_3 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_5 with cooldown: 3; turn 35; cmd: m u_5 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_3 with cooldown: 2; turn 36; cmd: m u_3 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_5 with cooldown: 2; turn 36; cmd: m u_5 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_3 with cooldown: 1; turn 37; cmd: m u_3 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_5 with cooldown: 1; turn 37; cmd: m u_5 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_3 with cooldown: 3; turn 39; cmd: m u_3 e
# [WARN] (match_tbx3kLtfhs4B) - Agent 0 tried to move unit u_5 with cooldown: 3; turn 39; cmd: m u_5 e
# ...

# %%
env.render(mode="ipython", width=1400, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;464b9a1d-2b56-11ec-af6b-c8b29bdfa6b4&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 562124210,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
# ...
